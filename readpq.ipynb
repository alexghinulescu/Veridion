# %%
import pandas as pd

# %%
df_parquet = r'data/veridion_product_deduplication_challenge.snappy.parquet'
df_csv = pd.read_csv('data/veridion_product_deduplication_challenge.snappy.csv')
pd.read_parquet(df_parquet, engine='auto')
# Out:
#                                                   unspsc  \
# 0      Sewing and stitchery and weaving equipment and...
# 1                 Electric alternating current AC motors
# 2                     Vehicle trim and exterior covering
# 3                                        Pipe connectors
# 4                                                  Doors
# ...                                                  ...
# 21941                                              Other
# 21942                     Processed and synthetic rubber
# 21943                            Fresh cut rose bouquets
# 21944  Vision correction or cosmetic eyewear and rela...
# 21945       Chocolate and sugars and sweetening products
#
#                          root_domain  \
# 0                  studio-atcoat.com
# 1                     worm-gears.net
# 2               customcarcoverco.com
# 3                    plumbmaster.com
# 4                           sogno.in
# ...                              ...
# 21941                   dsbridal.com
# 21942               50735-in.all.biz
# 21943             lilyofthevalley.uk
# 21944  getcontactlensesonline.com.au
# 21945           malagoschocolate.com
#
#                                                 page_url  \
# 0          https://studio-atcoat.com/1372696759/?idx=510
# 1              https://worm-gears.net/tag/worm-gear-box/
# 2      https://customcarcoverco.com/collections/vendo...
# 3      https://www.plumbmaster.com/search?q=wolverine...
# 4      http://www.sogno.in/product-detail-CST-HGD-331...
# ...                                                  ...
# 21941  https://www.dsbridal.com/index.php/sale/veils....
# 21942               https://50735-in.all.biz/group-goods
# 21943  https://www.lilyofthevalley.uk/product/luxurio...
# 21944  https://getcontactlensesonline.com.au/brand/al...
# 21945  https://malagoschocolate.com/collections/ready...
#
#                                        product_title  \
# 0                        Glimakra Warping Board (8m)
# 1                            NMRV Worm Gearbox Motor
# 2                           Nissan R33 GTR Car Cover
# 3                                  Flexible Fittings
# 4                   CST-HGD-33103 Hinged Closet Door
# ...                                              ...
# 21941                              15/16 Accessories
# 21942                General Mechanical Rubber Goods
# 21943                          Luxurious Rose Garden
# 21944  Dailies AquaComfort Plus Multifocal (30 Pack)
# 21945   Signature Dark Collection 85% Dark Chocolate
#
#                                          product_summary  \
# 0      The Glimakra Warping Board is designed for use...
# 1      The NMRV Worm Gearbox Motor is a high-efficien...
# 2      A custom car cover designed for the Nissan R33...
# 3      Flexible fittings for plumbing applications, a...
# 4      The CST-HGD-33103 Hinged Closet Door is a meti...
# ...                                                  ...
# 21941  Accessories designed for Sweet 15/16, availabl...
# 21942  A category of rubber goods designed for genera...
# 21943  The Luxurious Rose Garden is a stunning floral...
# 21944  A pack of 30 Dailies AquaComfort Plus Multifoc...
# 21945  A Signature Dark Collection product from Malag...
#
#                     product_name product_identifier  \
# 0                  Warping Board                 []
# 1             Worm Gearbox Motor                 []
# 2                      Car Cover                 []
# 3              Flexible Fittings                 []
# 4             Hinged Closet Door                 []
# ...                          ...                ...
# 21941                Accessories                 []
# 21942               Rubber Goods                 []
# 21943         Floral Arrangement                 []
# 21944  Multifocal Contact Lenses                 []
# 21945             Dark Chocolate                 []
#
#                             brand              intended_industries  \
# 0                            None                        [Textile]
# 1                            None                     [Industrial]
# 2                            None                     [Automotive]
# 3                            None                       [Plumbing]
# 4                             CST  [Home Appliances, Construction]
# ...                           ...                              ...
# 21941                        None                         [Retail]
# 21942                        None                  [Manufacturing]
# 21943  Lily Of The Valley Florist                  [Retail, Gifts]
# 21944                     Dailies                     [Healthcare]
# 21945           Malagos Chocolate                [Food & Beverage]
#
#                                  applicability  ...     form  \
# 0                       [use with floor looms]  ...       []
# 1                    [industrial applications]  ...       []
# 2      [protecting vehicles from the elements]  ...       []
# 3                     [plumbing installations]  ...       []
# 4                             [Closet Storage]  ...       []
# ...                                        ...  ...      ...
# 21941            [accessories for Sweet 15/16]  ...       []
# 21942                                       []  ...       []
# 21943           [gifting, decorative purposes]  ...       []
# 21944                      [vision correction]  ...       []
# 21945                                       []  ...  [Solid]
#
#                                                     size  \
# 0      [{'dimension': 'Length', 'qualitative': False,...
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 21941  [{'dimension': 'Diameter', 'qualitative': Fals...
# 21942                                                 []
# 21943  [{'dimension': 'Width', 'qualitative': False, ...
# 21944                                                 []
# 21945                                                 []
#
#                                                    color purity  \
# 0                                                     []     []
# 1      [{'original': 'Blue', 'simple': 'Blue'}, {'ori...     []
# 2                                                     []     []
# 3                                                     []     []
# 4                                                     []     []
# ...                                                  ...    ...
# 21941                                                 []     []
# 21942                                                 []     []
# 21943                                                 []     []
# 21944                                                 []     []
# 21945                                                 []     []
#
#       energy_efficiency pressure_rating  \
# 0                  None              []
# 1                  None              []
# 2                  None              []
# 3                  None              []
# 4                  None              []
# ...                 ...             ...
# 21941              None              []
# 21942              None              []
# 21943              None              []
# 21944              None              []
# 21945              None              []
#
#                                             power_rating  \
# 0                                                     []
# 1      [{'qualitative': False, 'type': 'min', 'unit':...
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 21941                                                 []
# 21942                                                 []
# 21943                                                 []
# 21944                                                 []
# 21945                                                 []
#
#        quality_standards_and_certifications  \
# 0                                        []
# 1                                        []
# 2                                        []
# 3                                        []
# 4                                        []
# ...                                     ...
# 21941                                    []
# 21942                                    []
# 21943                                    []
# 21944                                    []
# 21945                                    []
#
#                                   miscellaneous_features  \
# 0                                                     []
# 1      [Omnibearing installation, High radiation effi...
# 2      [Personalization with custom brand logos, grap...
# 3      [allows for movement, flexibility in installat...
# 4      [Italian craftsmanship, German engineering, Sm...
# ...                                                  ...
# 21941                      [part of the sale collection]
# 21942                                                 []
# 21943  [Product images available in various resolutions]
# 21944                                                 []
# 21945                                                 []
#
#                                              description
# 0      The "Warping Board" is designed for use with f...
# 1      The "Worm Gearbox Motor" is a high-efficiency ...
# 2      The "Car Cover" is a custom-designed cover tai...
# 3      "Flexible Fittings" are designed for plumbing ...
# 4      The "Hinged Closet Door" is a storage solution...
# ...                                                  ...
# 21941  "Accessories" are designed for use with Sweet ...
# 21942  "Rubber Goods" are designed for general mechan...
# 21943  "The 'Floral Arrangement' offered by Lily Of T...
# 21944  "Multifocal Contact Lenses" are designed for d...
# 21945  "Dark Chocolate" from Malagos Chocolate is a r...
#
# [21946 rows x 31 columns]

# %%
import pandas as pd
import numpy as np

df_paraquet = pd.read_parquet('data/veridion_product_deduplication_challenge.snappy.parquet')
df_test = df_paraquet.head(1000)

def aggregate_columns(series):
    if series.dtype == 'O':
        series = series.dropna().apply(lambda x: str(x) if isinstance(x, (dict, list, np.ndarray)) else x)
        return ', '.join(map(str, set(series)))
    else:
        return series.max()

df_new = df_test.groupby('product_title', as_index=False).aggregate(aggregate_columns)
df_new.to_parquet('output_data.parquet', engine='pyarrow')


print(df_new)
# Out:
#                                          product_title  \
# 0                                  "REFRIGERATE" Label
# 1                      #87 Granny Apple 1 - 05/15/2024
# 2    (3 pieces set) 15mm & 20mm Buttons made of Rec...
# 3    1 Micron Polypropylene Felt Liquid Filter Bag,...
# 4                                             1 ½ X 2"
# ..                                                 ...
# 942  Zootility Careful Key Antimicrobial Door Opene...
# 943                                c2g HDMI Wall Plate
# 944                             ta-C DLC Coated Collet
# 945                                     tetraCal-Ultra
# 946                                 ไขควงหัวท๊อกซ์พลัส
#
#                                                 unspsc  \
# 0                                               Labels
# 1                                     Glass adornments
# 2                                     Sewing fasteners
# 3                                              Filters
# 4                                               Valves
# ..                                                 ...
# 942  Decontamination aids and safety cleaning equip...
# 943                   Electrical hardware and supplies
# 944                   Tool attachments and accessories
# 945  Temperature and heat measuring instruments, Ma...
# 946                               Wrenches and drivers
#
#                 root_domain  \
# 0    apothecaryproducts.com
# 1      keithceroneglass.com
# 2          your-buttons.com
# 3           filtersmesh.com
# 4              cdivalve.com
# ..                      ...
# 942       lazarsluggage.com
# 943               ir815.com
# 944             chipx.co.nz
# 945            mesalabs.com
# 946      unior-thailand.com
#
#                                               page_url  \
# 0    https://shop.apothecaryproducts.com/products/r...
# 1    https://keithceroneglass.com/products/87-grann...
# 2    https://your-buttons.com/products/3-pieces-set...
# 3    https://www.filtersmesh.com/tag/1um-180410-liq...
# 4    https://www.cdivalve.com/products/pneumatic-va...
# ..                                                 ...
# 942  https://lazarsluggage.com/products/zootility-c...
# 943                 https://ir815.com/show/789738.html
# 944  https://www.chipx.co.nz/collections/all/flute-...
# 945  https://shop.mesalabs.com/subcategory/HiVol,MP...
# 946  http://unior-thailand.com/index.php/%E0%B9%84%...
#
#                                        product_summary  \
# 0    The "REFRIGERATE" Label is an advisory label d...
# 1    The "Granny Apple 1 - 05/15/2024" is a custom ...
# 2    The (3 pieces set) 15mm & 20mm Buttons made of...
# 3    A liquid filter bag constructed from polypropy...
# 4    Pneumatic valves with a size specification of ...
# ..                                                 ...
# 942  The Zootility Careful Key Antimicrobial Door O...
# 943  The c2g HDMI Wall Plate is a sophisticated and...
# 944  A collet designed for workholding applications...
# 945  A calibration tool for tetraCal-Ultra systems,...
# 946  An enhanced version of the torque screwdriver,...
#
#                              product_name  \
# 0                       REFRIGERATE Label
# 1                         Glass Sculpture
# 2                                 Buttons
# 3                       Liquid Filter Bag
# 4                        Pneumatic Valves
# ..                                    ...
# 942        Antimicrobial Door Opener Grip
# 943                       HDMI Wall Plate
# 944                                Collet
# 945  Calibration Tool, Calibration Device
# 946
#
#                       product_identifier         brand  \
# 0                 ['Part_Number: 40391']
# 1                                     []  Keith Cerone
# 2                                     []
# 3    ['Product_Code: PP-1um-180*410-FR']
# 4                                     []
# ..                                   ...           ...
# 942                                   []
# 943                                   []
# 944                                   []
# 945                                   []
# 946                                   []
#
#                                    intended_industries  \
# 0                                       ['Healthcare']
# 1                                              ['Art']
# 2                               ['Fashion' 'Crafting']
# 3                                    ['Manufacturing']
# 4    ['Pressure Washers' 'Air Compressors' 'Fire Su...
# ..                                                 ...
# 942                     ['Healthcare' 'Public Spaces']
# 943                             ['Home Entertainment']
# 944                                  ['Manufacturing']
# 945                      ['Technology'], ['Metrology']
# 946                                                 []
#
#                                          applicability  ... form  \
# 0                           ['Medication Information']  ...   []
# 1                              ['Decorative purposes']  ...   []
# 2    ['Wardrobe embellishment' 'Project embellishme...  ...   []
# 3                                ['liquid filtration']  ...   []
# 4    ['Pressure Washers' 'Air Compressors' 'Fire Su...  ...   []
# ..                                                 ...  ...  ...
# 942  ['door opening' 'button pressing' 'touch scree...  ...   []
# 943  ['Enhancing Connectivity And Aesthetics Of Hom...  ...   []
# 944                       ['Workholding Applications']  ...   []
# 945                                [], ['calibration']  ...   []
# 946                                                 []  ...   []
#
#                                                   size  \
# 0    [{'dimension': 'Length', 'qualitative': False,...
# 1                                                   []
# 2    [{'dimension': 'Diameter', 'qualitative': Fals...
# 3    [{'dimension': 'Length', 'qualitative': False,...
# 4    [{'dimension': 'Diameter', 'qualitative': Fals...
# ..                                                 ...
# 942                                                 []
# 943  [{'dimension': None, 'qualitative': True, 'typ...
# 944                                                 []
# 945                                                 []
# 946                                                 []
#
#                                                  color purity  \
# 0                                                   []     []
# 1    [{'original': 'Darc Blue-violet', 'simple': 'B...     []
# 2           [{'original': 'Beige', 'simple': 'Brown'}]     []
# 3                                                   []     []
# 4                                                   []     []
# ..                                                 ...    ...
# 942        [{'original': 'Copper', 'simple': 'Brown'}]     []
# 943                                                 []     []
# 944                                                 []     []
# 945                                                 []     []
# 946                                                 []     []
#
#     energy_efficiency pressure_rating power_rating  \
# 0                                  []           []
# 1                                  []           []
# 2                                  []           []
# 3                                  []           []
# 4                                  []           []
# ..                ...             ...          ...
# 942                                []           []
# 943                                []           []
# 944                                []           []
# 945                                []           []
# 946                                []           []
#
#      quality_standards_and_certifications  \
# 0                                      []
# 1                                      []
# 2                                      []
# 3                                      []
# 4                                      []
# ..                                    ...
# 942                                    []
# 943                                    []
# 944                                    []
# 945                                    []
# 946                                    []
#
#                                 miscellaneous_features  \
# 0                         ['Payment Options: ShopPay']
# 1    ['Limited series' 'Scheduled for completion on...
# 2    ['Sold out' 'Available for purchase using Shop...
# 3          ['Welded design' "Plastic 'F' flange ring"]
# 4                                                   []
# ..                                                 ...
# 942  ['Hook shape for extra control' 'Serves as a s...
# 943   ['Easy to install using basic tools and skills']
# 944  ['Available in compression direction' 'Part of...
# 945       ['temperature probe'], ['Item Number: TC14']
# 946                                                 []
#
#                                            description
# 0    The "REFRIGERATE" Label, identified by part nu...
# 1    The "Glass Sculpture" is a custom glass sculpt...
# 2    The "Buttons" is crafted from recycled shell m...
# 3    The "Liquid Filter Bag" is a liquid filter bag...
# 4    "1 ½ X 2\"" pneumatic valves are designed for ...
# ..                                                 ...
# 942  The "Antimicrobial Door Opener Grip" is design...
# 943  The "HDMI Wall Plate" is designed to enhance h...
# 944  The "Collet" is designed for workholding appli...
# 945  "Calibration Device" is a high-precision calib...
# 946
#
# [947 rows x 31 columns]
